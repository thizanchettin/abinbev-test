# %%
# %%sh
# pip install uv
# Out:
# Running cells with 'spark (3.12.13) (Python 3.12.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/thiago.souza.KEYRUSCORP/Documents/abinbev-test/abinvev-test/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
uv init

# %%
# %%sh
# uv sync

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%sh
# uv add requests pyspark
# uv add pytest --dev

# %%
# %%sh
# uv add pre-commit --dev

# %%
# %%sh
# cd /Workspace/Users/tazsouza@gmail.com/abinvev-test/
# uv run pre-commit install

# %%
uv add ruff --dev

# %%
uv run ruff check . --fix

# %%
from src.bronze.engine import main

main()

# %%
# %sql
SELECT * 
FROM json.`/Volumes/workspace/data_lake/bronze/breweries` limit 100

# %%
from src.silver.engine import main

main()

# %%
from src.gold.engine import main

main()
